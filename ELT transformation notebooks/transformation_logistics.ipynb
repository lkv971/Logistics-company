# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

df_freight = spark.read.table("LH_Logistics.dbo_Freight")
display(df_freight.limit(10))
# Out:
# StatementMeta(, b3c90857-1f91-40a5-ab1e-e8cca44eabf3, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 9b0b78d6-d53e-4339-b8a8-a8ee44dd0f42)

# %%
df_freight = df_freight.drop("WeightCubic")
df_freight = df_freight.withColumn("RevenuePerKg", df_freight["Revenue"] / df_freight["WeightKg"]) \
                        .withColumn("GoodsValuePerKg", df_freight["GoodsValue"] / df_freight["WeightKg"])
display(df_freight.limit(5))
# Out:
# StatementMeta(, b3c90857-1f91-40a5-ab1e-e8cca44eabf3, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0361cc68-1398-4d72-9794-2184b6e8c018)

# %%
df_costs = spark.read.table("LH_Logistics.dbo_Costs")
# Out:
# StatementMeta(, b3c90857-1f91-40a5-ab1e-e8cca44eabf3, 9, Finished, Available, Finished)

# %%
display(df_costs.limit(5))
# Out:
# StatementMeta(, b3c90857-1f91-40a5-ab1e-e8cca44eabf3, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 240b97cd-503c-4243-be20-a91a4b1c92b8)

# %%
df_costs["TruckID", "DriverID", "KmTravelled", "LitersConsumption", "LitersPer100Km", "FuelCost", "MaintenanceCost", "FixedCost", "TotalCost", "LitersPer100Km"]
# Out:
# StatementMeta(, b3c90857-1f91-40a5-ab1e-e8cca44eabf3, 11, Finished, Available, Finished)
# DataFrame[TruckID: int, DriverID: int, KmTravelled: int, LitersConsumption: decimal(10,2), LitersPer100Km: decimal(10,2), FuelCost: double, MaintenanceCost: decimal(10,2), FixedCost: decimal(10,2), TotalCost: decimal(10,2), LitersPer100Km: decimal(10,2)]

# %%
df_freight = df_freight.drop("GoodsValue", "GoodsValuePerKg")
df_freight.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("LH_Logistics.dbo_Freight")
df_costs.write.mode("overwrite").saveAsTable("LH_Logistics.dbo_Costs")
# Out:
# StatementMeta(, b3c90857-1f91-40a5-ab1e-e8cca44eabf3, 15, Finished, Available, Finished)
